# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data_loc = './data/'

# %%
#get common columns from the raw_data csv files for consistent data for all seasons
def get_common_columns(files):
    #Get set intersection of column-names of specified CSV files
    common_columns = set(pd.read_csv(files[0], nrows=0).columns)
    for f in files[1:]:
        common_columns &= set(pd.read_csv(f, nrows=0).columns)
    return common_columns

import glob
files = glob.glob(f'{data_loc}*.csv')

common_colums = list(get_common_columns(files))
#len(colums)
common_colums.sort()
common_colums
# Out:
# ['AC',
#  'AF',
#  'AR',
#  'AS',
#  'AST',
#  'AY',
#  'AwayTeam',
#  'B365A',
#  'B365D',
#  'B365H',
#  'BWA',
#  'BWD',
#  'BWH',
#  'Date',
#  'Div',
#  'FTAG',
#  'FTHG',
#  'FTR',
#  'HC',
#  'HF',
#  'HR',
#  'HS',
#  'HST',
#  'HTAG',
#  'HTHG',
#  'HTR',
#  'HY',
#  'HomeTeam',
#  'IWA',
#  'IWD',
#  'IWH',
#  'PSA',
#  'PSCA',
#  'PSCD',
#  'PSCH',
#  'PSD',
#  'PSH',
#  'VCA',
#  'VCD',
#  'VCH',
#  'WHA',
#  'WHD',
#  'WHH']

# %%
columns = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HS', 'AS', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR']
columns
# Out:
# ['Date',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HS',
#  'AS',
#  'HST',
#  'AST',
#  'HC',
#  'AC',
#  'HF',
#  'AF',
#  'HY',
#  'AY',
#  'HR',
#  'AR']

# %%
data = {}
year = 2018
for i in range(1,4):
    data[i] = pd.read_csv(f"{data_loc}{year}-{year+1}.csv", usecols=columns)
    year += 1
#     print(data[i].isnull().sum().sum()) # print number of null values

# %%
matches_data = pd.concat([data[1], data[2], data[3]])
#Replace names for consistency between ESPN page and downloaded .csv files
matches_data = matches_data.replace(
    {
        "Chievo": "Chievo Verona",
        "Inter": "Internazionale",
        "Roma" : "AS Roma",
        "Milan": "AC Milan",
        "Spal": "SPAL",
        "Verona": "Hellas Verona"
    }
)
matches_data
# Out:
#            Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HS  AS  HST  \
# 0    18/08/2018  Chievo Verona       Juventus     2     3   A   7  23    2
# 1    18/08/2018          Lazio         Napoli     1     2   A   9  11    5
# 2    19/08/2018        Bologna           SPAL     0     1   A   8  10    3
# 3    19/08/2018         Empoli       Cagliari     2     0   H   9  12    4
# 4    19/08/2018          Parma        Udinese     2     2   D   9  16    6
# ..          ...            ...            ...   ...   ...  ..  ..  ..  ...
# 375  23/05/2021        Bologna       Juventus     1     4   A  18  19    5
# 376  23/05/2021         Napoli  Hellas Verona     1     1   D  16   7    3
# 377  23/05/2021       Sassuolo          Lazio     2     0   H  10   9    5
# 378  23/05/2021         Spezia        AS Roma     2     2   D  18  14    9
# 379  23/05/2021         Torino      Benevento     1     1   D  12   9    7
#
#      AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     11   7   9   0   8   2   0   0   0
# 1      6   8   5   4   7   0   0   0   0
# 2      5  16  11   7   0   4   2   1   0
# 3      5  19  19   6   6   3   3   0   0
# 4      6  10  13   4   5   2   2   0   0
# ..   ...  ..  ..  ..  ..  ..  ..  ..  ..
# 375   11   7  16   3   0   1   2   0   0
# 376    4  13  25   5   3   3   4   0   0
# 377    2  11  15   3   3   2   1   1   0
# 378   10  13  14   5   2   0   1   0   0
# 379    3  17  10   8   3   0   2   0   0
#
# [1140 rows x 18 columns]

# %%
matches_data = matches_data.reset_index(drop=True)

# %%
matches_data.index += 1
matches_data['Date']= pd.to_datetime(matches_data['Date'])
matches_data
# Out:
#            Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HS  AS  HST  \
# 1    2018-08-18  Chievo Verona       Juventus     2     3   A   7  23    2
# 2    2018-08-18          Lazio         Napoli     1     2   A   9  11    5
# 3    2018-08-19        Bologna           SPAL     0     1   A   8  10    3
# 4    2018-08-19         Empoli       Cagliari     2     0   H   9  12    4
# 5    2018-08-19          Parma        Udinese     2     2   D   9  16    6
# ...         ...            ...            ...   ...   ...  ..  ..  ..  ...
# 1136 2021-05-23        Bologna       Juventus     1     4   A  18  19    5
# 1137 2021-05-23         Napoli  Hellas Verona     1     1   D  16   7    3
# 1138 2021-05-23       Sassuolo          Lazio     2     0   H  10   9    5
# 1139 2021-05-23         Spezia        AS Roma     2     2   D  18  14    9
# 1140 2021-05-23         Torino      Benevento     1     1   D  12   9    7
#
#       AST  HF  AF  HC  AC  HY  AY  HR  AR
# 1      11   7   9   0   8   2   0   0   0
# 2       6   8   5   4   7   0   0   0   0
# 3       5  16  11   7   0   4   2   1   0
# 4       5  19  19   6   6   3   3   0   0
# 5       6  10  13   4   5   2   2   0   0
# ...   ...  ..  ..  ..  ..  ..  ..  ..  ..
# 1136   11   7  16   3   0   1   2   0   0
# 1137    4  13  25   5   3   3   4   0   0
# 1138    2  11  15   3   3   2   1   1   0
# 1139   10  13  14   5   2   0   1   0   0
# 1140    3  17  10   8   3   0   2   0   0
#
# [1140 rows x 18 columns]

# %%
list(matches_data.HomeTeam.unique())
# Out:
# ['Chievo Verona',
#  'Lazio',
#  'Bologna',
#  'Empoli',
#  'Parma',
#  'Sassuolo',
#  'Torino',
#  'Atalanta',
#  'Juventus',
#  'Napoli',
#  'Cagliari',
#  'Fiorentina',
#  'Frosinone',
#  'Genoa',
#  'Internazionale',
#  'SPAL',
#  'Udinese',
#  'AS Roma',
#  'AC Milan',
#  'Sampdoria',
#  'Hellas Verona',
#  'Lecce',
#  'Brescia',
#  'Spezia',
#  'Crotone',
#  'Benevento']

# %%
# matches_data.to_csv('matches.csv', index=False)

# %%
import requests
from bs4 import BeautifulSoup, NavigableString
import datetime

# %%
url_base = 'https://www.transfermarkt.com'
season = 2018
df_dict = {
    "name" : [],
    "position" : [],
    "birth_date" : [],
    "nationality" : [],
    "number" : [],
    "season" : []
}

# %%
#Scraping info about a players
for i in range(3):
    season_url = f'{url_base}/serie-a/startseite/wettbewerb/IT1/plus/?saison_id={season}'
    print(f"Scraping season: {season}")
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36'}
    response = requests.get(season_url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    table = soup.find('div', class_='large-8 columns').find('table', class_='items')
    links = []
    for team in table.find_all('td', class_='hauptlink'):
        links.append(team.a['href'])
    del links[::2]
    
    print(f"Scraping teams...")
    for link in links:
        print(f"Scraping link: {link}")
        team_url = f'{url_base}{link}'        
        response = requests.get(team_url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        for player in soup.find_all('tr'): 
            number_class = player.find('div', class_='rn_nummer')
            if number_class != None and number_class.get_text() != '-': #if a player doesn't have a shirt number, it means that he didn't play for the team in that particular season so we can skip him
                df_dict['number'].append(number_class.get_text())
                name_class = player.find('td', class_='posrela')
                if name_class != None:
                    df_dict['name'].append(name_class.find('table', class_='inline-table').find('span').get_text())
                    df_dict['position'].append(name_class.find('table', class_='inline-table').tr.find_next_sibling().get_text())
                    df_dict['birth_date'].append(name_class.find_next_sibling().get_text()[:-5])
                    df_dict['nationality'].append(name_class.find_next_sibling().find_next_sibling().img.get('alt'))
                    df_dict['season'].append(season)
    season +=1
    
df_dict['number'] = [int(i) for i in df_dict['number']] #convert string to int 
df_dict['birth_date'] = [datetime.datetime.strptime(d, '%b %d, %Y').date() for d in df_dict['birth_date']] #convert string to date
# Out:
# Scraping season: 2018
# Scraping teams...
# Scraping link: /juventus-turin/startseite/verein/506/saison_id/2018
# Scraping link: /inter-mailand/startseite/verein/46/saison_id/2018
# Scraping link: /ac-mailand/startseite/verein/5/saison_id/2018
# Scraping link: /ssc-neapel/startseite/verein/6195/saison_id/2018
# Scraping link: /as-rom/startseite/verein/12/saison_id/2018
# Scraping link: /lazio-rom/startseite/verein/398/saison_id/2018
# Scraping link: /atalanta-bergamo/startseite/verein/800/saison_id/2018
# Scraping link: /ac-florenz/startseite/verein/430/saison_id/2018
# Scraping link: /fc-turin/startseite/verein/416/saison_id/2018
# Scraping link: /sampdoria-genua/startseite/verein/1038/saison_id/2018
# Scraping link: /us-sassuolo/startseite/verein/6574/saison_id/2018
# Scraping link: /udinese-calcio/startseite/verein/410/saison_id/2018
# Scraping link: /cagliari-calcio/startseite/verein/1390/saison_id/2018
# Scraping link: /genua-cfc/startseite/verein/252/saison_id/2018
# Scraping link: /fc-bologna/startseite/verein/1025/saison_id/2018
# Scraping link: /spal/startseite/verein/2722/saison_id/2018
# Scraping link: /parma-calcio-1913/startseite/verein/130/saison_id/2018
# Scraping link: /chievo-verona/startseite/verein/862/saison_id/2018
# Scraping link: /frosinone-calcio/startseite/verein/8970/saison_id/2018
# Scraping link: /fc-empoli/startseite/verein/749/saison_id/2018
# ['1', '22', '21', '32', '19', '24', '4', '3', '4', '15', '38', '43', '12', '37', '20', '16', '2', '23', '5', '30', '14', '6', '41', '39', '36', '34', '35', '44', '11', '40', '33', '10', '7', '18', '17', '1', '93', '27', '46', '37', '6', '23', '13', '29', '2', '33', '21', '77', '14', '8', '15', '5', '20', '87', '44', '18', '7', '16', '9', '10', '11', '61', '74', '99', '35', '25', '90', '84', '13', '33', '22', '17', '56', '68',
13', '59', '54', '3', '18', '65', '23', '5', '21', '70', '88', '87', '14', '8', '17', '33', '32', '8', '61', '71', '11', '53', '67', '27', '20', '10', '10', '77', '93', '26', '99', '60', '64', '45', '7', '9', '72', '52', '44', '1', '70', '16', '22', '67', '8', '14', '5', '47', '40', '15', '33', '3', '12', '91', '24', '44', '27', '2', '29', '6', '8', '11', '22', '13', '56', '4', '66', '26', '21', '18', '17', '23', '19', '55', '7', '10', '9', '69', '20', '25', '31', '57', '22', '91', '75', '12', '6', '15', '27', '32', '25', '4', '23', '34', '33', '3', '17', '92', '8', '88', '24', '16', '66', '5', '20', '21', '31' ...
# Scraping season: 2019
# Scraping teams...
# Scraping link: /juventus-turin/startseite/verein/506/saison_id/2019
# Scraping link: /ssc-neapel/startseite/verein/6195/saison_id/2019
# Scraping link: /inter-mailand/startseite/verein/46/saison_id/2019
# Scraping link: /ac-mailand/startseite/verein/5/saison_id/2019
# Scraping link: /as-rom/startseite/verein/12/saison_id/2019
# Scraping link: /ac-florenz/startseite/verein/430/saison_id/2019
# Scraping link: /lazio-rom/startseite/verein/398/saison_id/2019
# Scraping link: /atalanta-bergamo/startseite/verein/800/saison_id/2019
# Scraping link: /fc-turin/startseite/verein/416/saison_id/2019
# Scraping link: /cagliari-calcio/startseite/verein/1390/saison_id/2019
# Scraping link: /genua-cfc/startseite/verein/252/saison_id/2019
# Scraping link: /sampdoria-genua/startseite/verein/1038/saison_id/2019
# Scraping link: /us-sassuolo/startseite/verein/6574/saison_id/2019
# Scraping link: /udinese-calcio/startseite/verein/410/saison_id/2019
# Scraping link: /parma-calcio-1913/startseite/verein/130/saison_id/2019
# Scraping link: /fc-bologna/startseite/verein/1025/saison_id/2019
# Scraping link: /spal/startseite/verein/2722/saison_id/2019
# Scraping link: /brescia-calcio/startseite/verein/19/saison_id/2019
# Scraping link: /us-lecce/startseite/verein/1005/saison_id/2019
# Scraping link: /hellas-verona/startseite/verein/276/saison_id/2019
# ['1', '22', '21', '32', '19', '24', '4', '3', '4', '15', '38', '43', '12', '37', '20', '16', '2', '23', '5', '30', '14', '6', '41', '39', '36', '34', '35', '44', '11', '40', '33', '10', '7', '18', '17', '1', '93', '27', '46', '37', '6', '23', '13', '29', '2', '33', '21', '77', '14', '8', '15', '5', '20', '87', '44', '18', '7', '16', '9', '10', '11', '61', '74', '99', '35', '25', '90', '84', '13', '33', '22', '17', '56', '68', '93', '23', '2', '12', '20', '14', '21', '18', '79', '5', '16', '4', '39', '10', '77', '11', '8', '7', '19', '9', '63', '1', '25', '27', '12', '22', '22', '12', '26', '19', '33', '21', '13', '31', '6', '23', '2', '42', '5', '8', '17', '30', '3', '20', '9', '34', '18', '24', '7', '11', '99', '14', '95', '1', '83', '63', '77', '45', '44', '5', '20', '15', '28', '58', '11', '3', '57', '24', '2', '18', '42', '21', '16', '52', '7', '4', '6', '55', '27', '19', '53', '92', '34', '8', '56', '54', '22', '17', '14', '9', '60', '1', '24', '23', '31', '50', '90', '33', '3', '13', '26', '15', '4', '22', '49',
# 1888       M'Bala Nzola  Centre-Forward  1996-08-18      Angola      18
# 1889    Roberto Piccoli  Centre-Forward  2001-01-27       Italy      91
# 1890   Andrey Galabinov  Centre-Forward  1988-11-13    Bulgaria       9
#
#       season
# 1       2018
# 2       2018
# 3       2018
# 4       2018
# 5       2018
# ...      ...
# 1886    2020
# 1887    2020
# 1888    2020
# 1889    2020
# 1890    2020
#
# [1890 rows x 6 columns]

# %%
# df.to_csv('players.csv', index=False)

# %%
#Creating events, match_results and clubs dataframes
events_dict = {
    "event": [
        'Yellow card', 'Red card', 'Sub on', 'Sub off', 'Goal', 'Own goal', 'Corner',
    ]
}
match_results_dict = {
    "match_result" : [
        "H", "A", "D"
    ]
}
clubs_dict = {
    "club_name": all_data.HomeTeam.unique()
}
events_df = pd.DataFrame(events_dict)
events_df.index += 1
match_results_df = pd.DataFrame(match_results_dict)
match_results_df.index += 1
clubs_df = pd.DataFrame(clubs_dict)
clubs_df.index += 1

# %%
# events_df.to_csv('events.csv', index=False)
# match_results_df.to_csv('match_results.csv', index=False)
# clubs_df.to_csv('clubs.csv', index=False)

# %%
import re

#Obtain list of ids of teams for each of 3 seasons 
clubs_dict = {}
season = 2018
for i in range(3):
    clubs_dict[str(season+i)] = []
    season_url = f'https://www.espn.com/soccer/standings/_/league/ITA.1/season/{season+i}'
    response = requests.get(season_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    for club in soup.find('tbody', class_='Table__TBODY').find_all('tr'):
        clubs_dict[str(season+i)].append(re.search('[\d]+', club.td.div.a['href']).group())
clubs_dict
# Out:
# {'2018': ['111',
#   '114',
#   '105',
#   '110',
#   '103',
#   '104',
#   '239',
#   '112',
#   '2734',
#   '107',
#   '3997',
#   '118',
#   '3958',
#   '115',
#   '2925',
#   '109',
#   '3263',
#   '2574',
#   '4057',
#   '238'],
#  '2019': ['111',
#   '110',
#   '105',
#   '112',
#   '104',
#   '103',
#   '114',
#   '3997',
#   '119',
#   '109',
#   '115',
#   '107',
#   '118',
#   '2925',
#   '2734',
#   '239',
#   '3263',
#   '113',
#   '108',
#   '3958'],
#  '2020': ['110',
#   '103',
#   '105',
#   '111',
#   '114',
#   '112',
#   '104',
#   '3997',
#   '2734',
#   '119',
#   '3263',
#   '107',
#   '109',
#   '118',
#   '4056',
#   '2925',
#   '239',
#   '4059',
#   '3173',
#   '115']}

# %%
#Iterate through all of the teams match history for the conrete years to get the match ids
# match_ids = []
match_ids = {}
for season, club_ids in clubs_dict.items():
    print(f'Season: {season}')
    for club_id in club_ids: 
        print(f'Club: {club_id}')
        club_season_results_url = f'https://www.espn.com/soccer/team/results/_/id/{club_id}/season/{season}'
        response = requests.get(club_season_results_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        for match in soup.find('section', class_='Card').find_all('tr', class_='Table__TR Table__TR--sm Table__even'): #Get all matches played in the season for a team
            if re.search('[\d]+', match.a['href']).group() == club_id and match.select("td:nth-of-type(6)")[0].get_text() == 'Italian Serie A': #Get matches that were played only at home and filter out only 'Italian Serie A' matches..
                year = match.find_parent('div', class_='ResponsiveTable Table__results').div.get_text()[-4:]
                match_link = match.select("td:nth-of-type(3)")[0].a.find_next_sibling()['href'] #Get match id from the link and append it to the list of match ids 
                match_id = re.search('[\d]+', match_link).group()
#                 match_ids.append(re.search('[\d]+', match_link).group())
                date = match.td.get_text()[5:] + ' ' + year
                match_ids[str(match_id)] = datetime.datetime.strptime(date, '%b %d %Y').date()
#                 print(re.search('[\d]+', match_link).group())
match_ids
# Out:
# Season: 2018
# Club: 111
# Club: 114
# Club: 105
# Club: 110
# Club: 103
# Club: 104
# Club: 239
# Club: 112
# Club: 2734
# Club: 107
# Club: 3997
# Club: 118
# Club: 3958
# Club: 115
# Club: 2925
# Club: 109
# Club: 3263
# Club: 2574
# Club: 4057
# Club: 238
# Season: 2019
# Club: 111
# Club: 110
# Club: 105
# Club: 112
# Club: 104
# Club: 103
# Club: 114
# Club: 3997
# Club: 119
# Club: 109
# Club: 115
# Club: 107
# Club: 118
# Club: 2925
# Club: 2734
# Club: 239
# Club: 3263
# Club: 113
# Club: 108
# Club: 3958
# Season: 2020
# Club: 110
# Club: 103
# Club: 105
# Club: 111
# Club: 114
# Club: 112
# Club: 104
# Club: 3997
# Club: 2734
# Club: 119
# Club: 3263
# Club: 107
# Club: 109
# Club: 118
# Club: 4056
# Club: 2925
# Club: 239
# Club: 4059
# Club: 3173
# Club: 115
# {'522448': datetime.date(2019, 5, 19),
#  '522477': datetime.date(2019, 5, 3),
#  '522491': datetime.date(2019, 4, 20),
#  '522513': datetime.date(2019, 4, 6),
#  '522530': datetime.date(2019, 3, 30),
#  '522557': datetime.date(2019, 3, 8),
#  '522581': datetime.date(2019, 2, 15),
#  '522604': datetime.date(2019, 2, 2),
#  '522620': datetime.date(2019, 1, 21),
#  '522635': datetime.date(2018, 12, 29),
#  '522654': datetime.date(2018, 12, 22),
#  '522673': datetime.date(2018, 12, 7),
#  '522694': datetime.date(2018, 11, 24),
#  '522709': datetime.date(2018, 11, 3),
#  '522731': datetime.date(2018, 10, 20),
#  '522754': datetime.date(2018, 9, 29),
#  '522758': datetime.date(2018, 9, 26),
#  '522786': datetime.date(2018, 9, 16),
#  '522801': datetime.date(2018, 8, 25),
#  '522453': datetime.date(2019, 5, 19),
#  '522470': datetime.date(2019, 5, 5),
#  '522497': datetime.date(2019, 4, 22),
#  '522512': datetime.date(2019, 4, 7),
#  '522547': datetime.date(2019, 3, 17),
#  '522563': datetime.date(2019, 3, 3),
#  '522587': datetime.date(2019, 2, 17),
#  '522605': datetime.date(2019, 2, 2),
#  '522622': datetime.date(2019, 1, 20),
#  '522630': datetime.date(2018, 12, 29),
#  '522655': datetime.date(2018, 12, 22),
#  '522672': datetime.date(2018, 12, 8),
#  '522689': datetime.date(2018, 11, 25),
#  '522710': datetime.date(2018, 11, 2),
#  '522725': datetime.date(2018, 10, 28),
#  '522747': datetime.date(2018, 10, 7),
#  '522764': datetime.date(2018, 9, 26),
#  '522781': datetime.date(2018, 9, 15),
#  '522802': datetime.date(2018, 8, 25),
#  '522446': datetime.date(2019, 5, 26),
#  '583101': datetime.date(2020, 11, 2),
#  '583124': datetime.date(2020, 10, 19),
#  '583149': datetime.date(2020, 9, 27),
#  '583156': datetime.date(2020, 9, 19),
#  '582790': datetime.date(2021, 5, 15),
#  '582818': datetime.date(2021, 5, 9),
#  '582838': datetime.date(2021, 4, 24),
#  '582841': datetime.date(2021, 4, 21),
#  '582871': datetime.date(2021, 4, 3),
#  '582899': datetime.date(2021, 3, 13),
#  '582916': datetime.date(2021, 3, 3),
#  '582932': datetime.date(2021, 2, 20),
#  '582955': datetime.date(2021, 2, 6),
#  '582972': datetime.date(2021, 1, 24),
#  '582991': datetime.date(2021, 1, 9),
#  '583013': datetime.date(2021, 1, 3),
#  '583045': datetime.date(2020, 12, 16),
#  '583054': datetime.date(2020, 12, 13),
#  '583075': datetime.date(2020, 11, 30),
#  '583096': datetime.date(2020, 11, 8),
#  '583139': datetime.date(2020, 11, 4),
#  '583113': datetime.date(2020, 10, 24),
#  '583153': datetime.date(2020, 9, 20),
#  '582784': datetime.date(2021, 5, 23),
#  '582802': datetime.date(2021, 5, 12),
#  '582823': datetime.date(2021, 5, 2),
#  '582849': datetime.date(2021, 4, 21),
#  '582858': datetime.date(2021, 4, 18),
#  '582873': datetime.date(2021, 4, 3),
#  '582897': datetime.date(2021, 3, 14),
#  '582926': datetime.date(2021, 2, 27),
#  '582941': datetime.date(2021, 2, 12),
#  '582966': datetime.date(2021, 1, 30),
#  '582983': datetime.date(2021, 1, 16),
#  '583009': datetime.date(2021, 1, 6),
#  '583020': datetime.date(2020, 12, 23),
#  '583056': datetime.date(2020, 12, 13),
#  '583070': datetime.date(2020, 11, 29),
#  '583095': datetime.date(2020, 11, 8),
#  '583102': datetime.date(2020, 10, 31),
#  '583129': datetime.date(2020, 10, 18),
#  '583147': datetime.date(2020, 9, 28),
#  '582796': datetime.date(2021, 5, 16),
#  '582814': datetime.date(2021, 5, 8),
#  '582833': datetime.date(2021, 4, 25),
#  '582860': datetime.date(2021, 4, 11),
#  '582886': datetime.date(2021, 3, 21),
#  '582907': datetime.date(2021, 3, 7),
#  '582915': datetime.date(2021, 3, 3),
#  '582937': datetime.date(2021, 2, 19),
#  '582954': datetime.date(2021, 2, 5),
#  '582973': datetime.date(2021, 1, 23),
#  '582992': datetime.date(2021, 1, 10),
#  '583010': datetime.date(2021, 1, 3),
#  ...}

# %%
len(match_ids)
# Out:
# 1140

# %%
def get_soup(id):
    match_url = f'https://www.espn.com/soccer/commentary?gameId={id}'
    response = requests.get(match_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    if soup.find('h1', class_='Error404__Title') != None:
        return soup, False
    return soup, True

# %%
soup = None
date = None
for match_id, date in match_ids.items():
    date = date
    soup, flag = get_soup(522448)
    while not flag:
        print("Server error, retrying..")
        soup, flag = get_soup(522448)

# %%
match_url = f'https://www.espn.com/soccer/commentary?gameId=522448'
response = requests.get(match_url)
soup = BeautifulSoup(response.content, 'html.parser')
date
# Out:
# datetime.date(2019, 5, 19)

# %%
season = int(soup.find('div', class_='game-details header').get_text().strip()[:4])
teams = soup.find_all('div', class_='team-info-wrapper')
teams = [teams[0].span.get_text(), teams[1].span.get_text()]
match_id = matches_data[(matches_data['HomeTeam'] == teams[0]) & (matches_data['AwayTeam'] == teams[1]) & (matches_data['Date'] == np.datetime64(date))].index[0]

for idx, team_table in enumerate(soup.find('div', id="gamepackage-game-lineups").find_all('table')):
    current_team = teams[idx]
    for player in team_table.find_all('div', class_="accordion-item"):
        player_name = player.a.get_text().strip()
        player_number_element = player.find('span', style=" display:inline-block; width: 24px;")
        if player_number_element != None:
            player_number = int(player_number_element.get_text())
            if player.parent.parent.parent.find_previous_sibling('thead').get_text().strip() == 'Substitutes': #Hideous, but gets the job done
                is_substitute = True
            else:
                is_substitute = False
        else:
            player_number = int(player.find('span', class_='name').contents[-1].strip())
            is_substitute = True
        print(player_name, player_number, is_substitute, current_team)
        
        player_fk = df[(df['name'] == player_name) & (df['number'] == player_number) & (df['season'] == season)]
        if player_fk.empty:
            print("Name inconsistency.. searching using part of the name")
            name = player_name.split()
            name.reverse()
            player_fk = df[(df['name'].str.contains('|'.join(name))) & (df['number'] == player_number) & (df['season'] == season)].index[0]
        else:
            player_fk = player_fk.index[0]
#         print(player_fk)
        club_fk = clubs_df[clubs_df['club_name'] == current_team]
        
    print('\n')
print(season)
print(np.datetime64(date))
print(match_id)
# matches_data.info()
# Out:
# Wojciech Szczesny 1 False Juventus
# Leonardo Bonucci 19 False Juventus
# Andrea Barzagli 15 False Juventus
# Mario Mandzukic 17 True Juventus
# Alex Sandro 12 False Juventus
# Federico Bernardeschi 33 True Juventus
# João Cancelo 20 False Juventus
# Miralem Pjanic 5 False Juventus
# Emre Can 23 False Juventus
# Blaise Matuidi 14 False Juventus
# Moise Kean 18 True Juventus
# Juan Cuadrado 16 False Juventus
# Cristiano Ronaldo 7 False Juventus
# Paulo Dybala 10 False Juventus
# Giorgio Chiellini 3 True Juventus
# Martín Cáceres 4 True Juventus
# Carlo Pinsoglio 21 True Juventus
# Leonardo Spinazzola 37 True Juventus
# Mattia De Sciglio 2 True Juventus
# Daniele Rugani 24 True Juventus
# Rodrigo Bentancur 30 True Juventus
# Mattia Del Favero 32 True Juventus
# Hans Nicolussi Caviglia 41 True Juventus
#
#
# Pierluigi Gollini 95 False Atalanta
# Berat Djimsiti 19 False Atalanta
# Andrea Masiello 5 False Atalanta
# Hans Hateboer 33 False Atalanta
# Remo Freuler 11 False Atalanta
# Marten de Roon 15 False Atalanta
# Alejandro Gómez 10 False Atalanta
# Name inconsistency.. searching using part of the name
# Mario Pasalic 88 True Atalanta
# Robin Gosens 8 False Atalanta
# Gianluca Mancini 23 True Atalanta
# Timothy Castagne 21 False Atalanta
# Duván Zapata 91 False Atalanta
# Josip Ilicic 72 False Atalanta
# Musa Barrow 99 True Atalanta
# Francesco Rossi 31 True Atalanta
# Etrit Berisha 1 True Atalanta
# Matteo Pessina 22 True Atalanta
# Ibañez 41 True Atalanta
# Name inconsistency.. searching using part of the name
# Arkadiusz Reca 7 True Atalanta
#
#
# 2018
# 2019-05-19
# 366
